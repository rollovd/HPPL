# %%
from schelling3D import Schelling3D

# %%
from tqdm import tqdm_notebook

num_of_players = 2
n = 38
num_of_iterations = 80 # 220 итераций для n=35 примерно 7-8 минут работает
r = 0.375
# r = 1

schelling3d = Schelling3D(num_of_players=num_of_players, n=n, r=r, save_images=True)

for i in tqdm_notebook(range(num_of_iterations)):
    schelling3d.play()
    schelling3d.save_all_images(total_num_of_iterations=num_of_iterations, num_of_iteration=i, save_img=True)

print('Gifs')
schelling3d.create_gifs()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # This is added back by InteractiveShellApp.init_path()
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-89c0a65e2ab7> in <module>()
#      11 for i in tqdm_notebook(range(num_of_iterations)):
#      12     schelling3d.play()
# ---> 13     schelling3d.save_all_images(total_num_of_iterations=num_of_iterations, num_of_iteration=i, save_img=True)
#      14
#      15 print('Gifs')
#
# <ipython-input-1-1dfcbb908758> in save_all_images(self, total_num_of_iterations, num_of_iteration, save_img)
#     164
#     165     def save_all_images(self, total_num_of_iterations=None, num_of_iteration=None, save_img=False):
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     155       raise ValueError('Mountpoint must not be a symlink')
#     156     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# --> 157       raise ValueError('Mountpoint must not already contain files')
#     158     if not _os.path.isdir(mountpoint) and _os.path.exists(mountpoint):
#     159       raise ValueError('Mountpoint must either be a directory or not exist')
#
# ValueError: Mountpoint must not already contain files

# %%
def plot_want_to_move(schellings, num_of_iter):
  plt.figure(figsize=(14,11))
  plt.title('Number of households that want to move', fontsize=20)

  for instance in schellings:
    r = instance.r
    want_to_move = instance.want_to_move
    
    plt.plot(np.arange(1, num_of_iter + 1, dtype=int), want_to_move, label=f'{int(r / 0.125)}/8 surrounds')
    plt.legend(fontsize=16)

    plt.tick_params(axis='both', labelsize=20)
    plt.xlabel('Number of iterations', fontsize=20)
    plt.ylabel('Number of people wants to move', fontsize=20)


percents = np.linspace(0, 1, 9)

num_of_players = 2
num_of_iterations = 200
n = 25

schellings = []
for percent in tqdm_notebook(percents):
  schelling3d = Schelling3D(num_of_players=num_of_players, n=n, r=percent)

  for i in range(num_of_iterations):
    schelling3d.play()

  schellings.append(schelling3d)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
plot_want_to_move(schellings, num_of_iterations)

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # This is added back by InteractiveShellApp.init_path()
# ...
# Gifs
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:173: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:200: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
 # import imageio
# import numpy as np 
# import cv2   

# #Create reader object for the gif
# gif1 = imageio.get_reader('/content/drive/MyDrive/Sk/HPPL/Project/0.7_35_percent_of_agents_folder/0.7_35_agents_3d.gif')
# gif2 = imageio.get_reader('/content/drive/MyDrive/Sk/HPPL/Project/0.7_35_percent_of_agents_folder/0.7_35_agents_projection.gif')

# #If they don't have the same number of frame take the shorter
# number_of_frames = min(gif1.get_length(), gif2.get_length()) 

# #Create writer object
# new_gif = imageio.get_writer('/content/drive/MyDrive/Sk/HPPL/Project/0.7_35_percent_of_agents_folder/combine_check.gif')

# for frame_number in tqdm_notebook(range(number_of_frames)):
#     img1 = gif1.get_next_data()
#     img2 = gif2.get_next_data()

#     img1 = cv2.resize(img1, (864, 504))
#     #here is the magic
#     new_image = np.hstack((img1, img2))
#     new_gif.append_data(new_image)

# gif1.close()
# gif2.close()    
# new_gif.close()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# ...

# %%
# from tqdm import tqdm_notebook
# import glob
# import imageio

# # name = 'Random'

# # for i in tqdm_notebook(range(500)):
# #     c.simulate(i, save_img=True, name_folder=name)

# def create_gif(filenames):
#     images = []
#     for filename in tqdm_notebook(filenames):
#         images.append(imageio.imread(filename))

#     imageio.mimsave(end_, images)

# three_dim_folder = f"/content/drive/MyDrive/Sk/HPPL/Project/0.7_percent_of_agents_folder/*.png"
# projection_folder = f"/content/drive/MyDrive/Sk/HPPL/Project/0.7_percent_of_agents_folder_projections/*.png"

# end_three = f"/content/drive/MyDrive/Sk/HPPL/Project/0.7_percent_of_agents_folder.gif"
# end_projection = f"/content/drive/MyDrive/Sk/HPPL/Project/0.7_percent_of_agents_folder_projection.gif"

# filenames_3d = glob.glob(three_dim_folder)
# filenames_proj = glob.glob(projection_folder)

# create_gif(filenames_3d)
# create_gif(filenames_proj)

# # images_3d = []
# # for filename in tqdm_notebook(filenames_3d):
# #     images.append(imageio.imread(filename))

# # imageio.mimsave(end_, images_3d)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if sys.path[0] == '':
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-138-fa46413b04aa> in <module>()
#      26 filenames_proj = glob.glob(projection_folder)
#      27
# ---> 28 create_gif(filenames_3d)
#      29 create_gif(filenames_proj)
#      30
#
# <ipython-input-138-fa46413b04aa> in create_gif(filenames)
#      11     images = []
#      12     for filename in tqdm_notebook(filenames):
# ---> 13         images.append(imageio.imread(filename))
#      14
#      15     imageio.mimsave(end_, images)
#
# /usr/local/lib/python3.6/dist-packages/imageio/core/functions.py in imread(uri, format, **kwargs)
#     219
#     220     # Get reader and read first
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

from tqdm import tqdm_notebook

num_of_players = 2
n = 25
num_of_iterations = 130

schelling3d = Schelling3D(num_of_players=num_of_players, n=n, r=0.7)

z, x, y = schelling3d.playing_field.nonzero()


fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')

ax.set_title('Iteration', fontsize=16)
ax.scatter(x, y, -z, zdir='z', c= 'red')

ax.set_xlabel('$X$', fontsize=18)
ax.set_ylabel('$Y$', fontsize=18)
ax.set_zlabel(r'$Z$', fontsize=14)
# Out:
# Text(0.5, 0, '$Z$')

# %%
for i in range(num_of_iterations):
    schelling3d.play()

# %%
z, x, y = schelling3d.playing_field.nonzero()


fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, -z, zdir='z', c= 'red')

ax.set_xlabel('$X$', fontsize=18)
ax.set_ylabel('$Y$', fontsize=18)
ax.set_zlabel(r'$Z$', fontsize=14)
# Out:
# Text(0.5, 0, '$Z$')

# %%
check = schelling3d.playing_field

# %%
import seaborn as sns

def draw_projections(data):

    f,(ax1,ax2,ax3, axcb) = plt.subplots(1,4, 
            gridspec_kw={'width_ratios':[1,1,1,0.08]})
    
    f.set_figheight(7)
    f.set_figwidth(25)
    
    ax1.get_shared_y_axes().join(ax2,ax3)
    g1 = sns.heatmap(data.sum(axis=0),cmap="YlGnBu",cbar=False,ax=ax1)
    g1.set_ylabel('')
    g1.set_xlabel('')

    g2 = sns.heatmap(data.sum(axis=1),cmap="YlGnBu",cbar=False,ax=ax2)
    g2.set_ylabel('')
    g2.set_xlabel('')
    g2.set_yticks([])

    g3 = sns.heatmap(data.sum(axis=2),cmap="YlGnBu",ax=ax3, cbar_ax=axcb)
    g3.set_ylabel('')
    g3.set_xlabel('')
    g3.set_yticks([])

    # may be needed to rotate the ticklabels correctly:
    for ax in [g1,g2,g3]:
        tl = ax.get_xticklabels()
        ax.set_xticklabels(tl, rotation=90)
        tly = ax.get_yticklabels()
        ax.set_yticklabels(tly, rotation=0)


draw_projections(check)

# %%
# !pip install plotly
# !pip install plotly --upgrade
# Out:
# ...
# Requirement already up-to-date: plotly in /usr/local/lib/python3.6/dist-packages (4.14.1)
# ...
